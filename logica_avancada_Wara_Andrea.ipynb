# %% [markdown]
# <a href="https://colab.research.google.com/github/waralimachi066-create/Teste_Analytics_Wara-Limachi_/blob/Python/logica_avancada_Wara_Andrea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ATIVIDADE 2 - BREAK - REVISÃO
#Qual a quantidade comprada pelo cliente em uma loja com variação de 150 produtos?
comprados = 0
for produto in range(0,150):
    compra = input("Qual o produto que você deseja? Coloque 'encerrar' para terminar. ")
    if compra.lower() == "encerrar": #Lower é para deixar tudo em minúsculo
        break
    else:
        comprados = comprados + 1
print("A quantidade de produtos comprados foi:", comprados)
# Out:
# Qual o produto que você deseja? Coloque 'encerrar' para terminar. Banana
# Qual o produto que você deseja? Coloque 'encerrar' para terminar. encerrar
# A quantidade de produtos comprados foi: 1

# %%
#WHILE, funciona até que a condição seja verdadeira
senha = input("Digite a senha: ")
correta = "2c2r"
while senha != correta:
    print("Errado!")
    senha = input("Faça uma nova tentativa: ")
print("Você descobriu a senha!")
# Out:
# Digite a senha: 64521
# Errado!
# Faça uma nova tentativa: 2c2r
# Você descobriu a senha!

# %%
#DESAFIO - DIA 1
comando1 = input("Vamos começar? S/N: ")
print("----------------------------------------------")
comando2 = "N"
cadastrados = 0
while comando1 != comando2:
    n = input("Nome: ")
    p = input("Preço: ")
    q = input("Quantidade em estoque: ")
    print("----------------------------------------------")
    print(f"O produto é {n}, o preço é R${p} e temos {q} em estoque")
    cadastrados = cadastrados + 1
    print("----------------------------------------------")
    comando1 = input("Vamos continuar? S/N: ")
    print("----------------------------------------------")
print(f"Foram cadastrados {cadastrados} produtos!")
# Out:
# Vamos começar? S/N: S
# ----------------------------------------------
# Nome: Garrafa
# Preço: 20
# Quantidade em estoque: 40
# ----------------------------------------------
# O produto é Garrafa, o preço é R$20 e temos 40 em estoque
# ----------------------------------------------
# Vamos continuar? S/N: S
# ----------------------------------------------
# Nome: Mouse
# Preço: 20
# Quantidade em estoque: 40
# ----------------------------------------------
# O produto é Mouse, o preço é R$20 e temos 40 em estoque
# ----------------------------------------------
# Vamos continuar? S/N: N
# ----------------------------------------------
# ----------------------------------------------
# Foram cadastrados 2 produtos no total!

# %%
#EXEMPLOS DE TUPLAS 1 - ELEMENTO VOGAL
vogais = ("a", "e", "i", "o", "u")
print(vogais[0])
print(vogais[1])
# Out:
# a
# e

# %%
#EXEMPLOS DE TUPLAS 2 - LETRAS
nome = "Juliana"
print(nome)
print(nome[0])
print(nome[3])
# Out:
# Juliana
# J
# i

# %%
#EXEMPLOS DE TUPLAS 3 - COMPOSTAS
vogais = ("a", 2, "e", "i", "o", "u", 1)
print(vogais)
print(vogais[1])
# Out:
# ('a', 2, 'e', 'i', 'o', 'u', 1)
# 2

# %%
#EXEMPLO DE LISTA - IMPRIMIR APENAS UMA INFORMAÇÃO DA LISTA
letras = ["c", "o", "t", "e", "n"]
print(letras)
print(letras[0])
print(letras[1])
print(letras[2])
print(letras[3])
# Out:
# ['c', 'o', 't', 'e', 'n']
# c
# o
# t
# e

# %% [markdown]
# **Acima são exemplos de tuplas**
#
# #TUPLAS - Imutável, Indexada, organizados em uma única linha:
#
# Usamos as tuplas em situações em que não haverá necessidade de adicionar, remover ou alterar elementos de um grupo de itens.
#
# Exemplos: meses do ano, os dias da semana, as estações do ano, etc.
#
# Nesses casos, não haverá mudança nesses itens.
#
# #Estrutura:
# alunas = ("Caroline", "Letícia", "Paloma")
#
# notas_q3= (7.5, 8.9, 6.3)
# #Diferenciação:
# itens1 = ("item1")
#
# print(type(itens1)) #<class 'str'>
#
# itens2 = ("item1",)
#
# print(type(itens2)) **#<class 'tuple'>**
#
# #LISTAS - Mutável, Indexada.
#
# #Estrutura:
# print(lista[índice])
#
# alunas = ["Caroline", "Letícia", "Paloma"]
#
# notas_q3= [7.5, 8.9, 6.3]

# %%
#ATIVIDADE - Eu usei a lista
faltas = ["0","3","0","0","0","1","2","1","1","0"]
n = int(input("Digite o número do indíce da aluna: "))
print("Quantidade de faltas:",faltas[n-1]) #Pois sempre começa com o 0, logo não seria possível acessar o número "um" da lista
# Out:
# Digite o número do indíce da aluna: 2
# Quantidade de faltas: 3

# %%
#ALTERAR O VALOR DA LISTA
letras = ["c", "o", "t", "e", "n"]
print(letras)
letras[0] = "b"
letras[2] = 13
letras[4] = "p"
print(letras)
# Out:
# ['c', 'o', 't', 'e', 'n']
# ['b', 'o', 13, 'e', 'p']

# %%
#ATIVIDADE PARA SUBSTITUIR ELEMENTOS NA LISTA
"""
Após Anna escrever a lista com as notas das alunas, ela percebeu que cometeu
dois erros na conferência da lista de presença. A terceira aluna da lista
teve na verdade duas faltas ao invés de zero e a oitava aluna teve três faltas
ao invés de uma.
"""
faltas = [0,3,0,0,0,1,2,1,1,0]
faltas[2] = 2 #A contagem começa pelo 0!!!
faltas[7] = 3
print("Lista corrigida:", faltas)
# Out:
# Lista corrigida: [0, 3, 2, 0, 0, 1, 2, 3, 1, 0]

# %%
#DESAFIO - DIA 1 - parte 2
comando1 = input("Vamos começar? S/N: ")
print("----------------------------------------------")
comando2 = "N"
cadastrados = 0
while comando1 != comando2:
    n = input("Nome: ")
    p = input("Preço: ")
    q = input("Quantidade em estoque: ")
    cadastrado_lista = [n,p,q]
    print("----------------------------------------------")
    print(f"Produto Cadastrado:", cadastrado_lista)
    cadastrados = cadastrados + 1
    print("----------------------------------------------")
    comando1 = input("Vamos continuar? S/N: ")
    print("----------------------------------------------")
cadastrado_lista = [n,p,q]
print(f"Foram cadastrados {cadastrados} produtos!")
# Out:
# Vamos começar? S/N: S
# ----------------------------------------------
# Nome: Teclado
# Preço: 60
# Quantidade em estoque: 30
# ----------------------------------------------
# Produto Cadastrado: ['Teclado', '60', '30']
# ----------------------------------------------
# Vamos continuar? S/N: S
# ----------------------------------------------
# Nome: Monitor
# Preço: 300
# Quantidade em estoque: 40
# ----------------------------------------------
# Produto Cadastrado: ['Monitor', '300', '40']
# ----------------------------------------------
# Vamos continuar? S/N: N
# ----------------------------------------------
# Foram cadastrados 2 produtos!

# %%
#Podemos verificar o tamanho de uma lista ou de uma tupla usando a função
vogais = ("a", "e", "i", "o", "u")
print(len(vogais))

letras = ["c", "o", "t", "e", "n"]
print(len(letras))

nome = "Juliana"
print(len(nome))
# Out:
# 5
# 5
# 7

# %%
#.append()
"""
Sabemos que a lista é uma estrutura que pode ser alterada.
Sendo assim, ela pode crescer.
Podemos fazer isso usando a função
.append()
"""
letras = ["c", "o", "t", "e", "n"]
letras.append("s")
print(letras)
print("Tamanho da lista: ", len(letras))
letras.append(15)
print(letras)
print("Tamanho da lista: ", len(letras))
# Out:
# ['c', 'o', 't', 'e', 'n', 's']
# Tamanho da lista:  6
# ['c', 'o', 't', 'e', 'n', 's', 15]
# Tamanho da lista:  7

# %%
#.append() - PARTE 2
lista = []
lista.append("UFABC")
print(lista)
print("Tamanho da lista: ", len(lista))

lista.append(2022)
print(lista)
print("Tamanho da lista: ", len(lista))
# Out:
# ['UFABC']
# Tamanho da lista:  1
# ['UFABC', 2022]
# Tamanho da lista:  2

# %%
#ATIVIDADE - .append e len
lista = []
repita = True #Assumimos que o While é verdadeiro para usar o break depois.
while repita:
    comando = input("Insira a sua tarefa: ")
    if comando.lower() == "fim":
        repita = False
        print("Tarefas adicionadas!")
    else: #Para somente não adicionar o fim
        lista.append(comando)
print("----------------------------------------------")
print("Deveres à fazer:", len(lista))
# Out:
# Insira a sua tarefa: DOMRIR
# Insira a sua tarefa: DOMRIR
# Insira a sua tarefa: DOmri
# Insira a sua tarefa: fim
# Tarefas adicionadas!
# ----------------------------------------------
# Deveres à fazer: 3

# %%
#DESAFIO - DIA 1 - parte 3 - estoque com lista unidificada
comando1 = input("Vamos começar? S/N: ")
print("----------------------------------------------")
comando2 = "N"
cadastrados = 0
estoque = [] #para unir
while comando1 != comando2:
    n = input("Nome: ")
    p = input("Preço: ")
    q = input("Quantidade em estoque: ")
    cadastrado_lista = [n,p,q]
    print("----------------------------------------------")
    print(f"Produto Cadastrado:", cadastrado_lista)
    cadastrados = cadastrados + 1
    print("-----------")
    comando1 = input("Vamos continuar? S/N: ")
    print("-----------")
    estoque.append(cadastrado_lista) #Adicionar
print(f"Foram cadastrados {cadastrados} produtos!")
print(estoque)
# Out:
# Vamos começar? S/N: S
# ----------------------------------------------
# Nome: ROBO
# Preço: 200000
# Quantidade em estoque: 20
# ----------------------------------------------
# Produto Cadastrado: ['ROBO', '200000', '20']
# -----------
# Vamos continuar? S/N: S
# -----------
# Nome: Aspirador
# Preço: 300
# Quantidade em estoque: 20
# ----------------------------------------------
# Produto Cadastrado: ['Aspirador', '300', '20']
# -----------
# Vamos continuar? S/N: S
# -----------
# Nome: Telefone
# Preço: 500
# Quantidade em estoque: 10
# ----------------------------------------------
# Produto Cadastrado: ['Telefone', '500', '10']
# -----------
# Vamos continuar? S/N: N
# -----------
# Foram cadastrados 3 produtos!
# [['ROBO', '200000', '20'], ['Aspirador', '300', '20'], ['Telefone', '500', '10']]

# %%
#For i in range - EXPLICAÇÃO DO i EM FOR - parte 1
notas = [3, 7, 9, 10, 5]
for i in notas:
	print("A aluna tirou nota", i)
# Out:
# A aluna tirou nota 3
# A aluna tirou nota 7
# A aluna tirou nota 9
# A aluna tirou nota 10
# A aluna tirou nota 5

# %%
#For i in range - EXPLICAÇÃO DO i EM FOR - parte 2
meses = ("Janeiro", "Fevereiro", "Março", "Abril")
for mes in meses:
	print("O mês atual é", mes)
# Out:
# O mês atual é Janeiro
# O mês atual é Fevereiro
# O mês atual é Março
# O mês atual é Abril

# %%
#DESAFIO - DIA 1 - parte 4 - imprimir cada elemento do estoque
comando1 = input("Vamos começar? S/N: ")
print("___________________________________________")
comando2 = "N"
estoque = [] #para unir
while comando1 != comando2:
    n = input("Nome: ")
    p = input("Preço: ")
    q = input("Quantidade em estoque: ")
    cadastrado_lista = [n,p,q]
    print("----------------------------------------------")
    print(f"Produto Cadastrado:", cadastrado_lista)
    print("___________________________________________")
    comando1 = input("Vamos continuar? S/N: ")
    print("___________________________________________")
    estoque.append(cadastrado_lista) #Adicionar no estoque

print(f"Foram cadastrados", len(estoque), "produtos!")
print("----------------------------------------------")
for quantidade in estoque:
    print("Produto/ Preço/ Quantidade:\n", quantidade)
# Out:
# Vamos começar? S/N: S
# ___________________________________________
# Nome: Banana
# Preço: 10
# Quantidade em estoque: 40
# ----------------------------------------------
# Produto Cadastrado: ['Banana', '10', '40']
# ___________________________________________
# Vamos continuar? S/N: S
# ___________________________________________
# Nome: Morango
# Preço: 10
# Quantidade em estoque: 40
# ----------------------------------------------
# Produto Cadastrado: ['Morango', '10', '40']
# ___________________________________________
# Vamos continuar? S/N: N
# ___________________________________________
# Foram cadastrados 2 produtos!
# ----------------------------------------------
# Produto/ Preço/ Quantidade:
#  ['Banana', '10', '40']
# Produto/ Preço/ Quantidade:
#  ['Morango', '10', '40']

# %%
#Dia 2 - estamos agora no slide 129 e começamos no 102

# Cria uma lista sem nenhum elemento.
lista_vazia = []
print("Lista vazia: ", lista_vazia)
print("Tipo de uma lista: ", type(lista_vazia))
print("___________________________________________")

lista_inteiros = [10, 20, 30, 40]
print("Lista de inteiros: ", lista_inteiros)
print("___________________________________________")

lista_tipos_diferentes = ["George", "Orwell", 1984]
print("Lista de elementos com tipos diferentes: ", lista_tipos_diferentes)
# Out:
# Lista vazia:  []
# Tipo de uma lista:  <class 'list'>
# ___________________________________________
# Lista de inteiros:  [10, 20, 30, 40]
# ___________________________________________
# Lista de elementos com tipos diferentes:  ['George', 'Orwell', 1984]

# %%
#ATIVIDADE - EQUAÇÕES COM LISTAS, calcular a média das notas:
lista_notas = [3.4, 6.6, 8, 9, 10, 9.5, 8.8, 4.3]
soma = 0
for nota in lista_notas:
    soma = soma+nota
media = soma/len(lista_notas)
print('Média =', media)
# Out:
# Média = 7.449999999999999

# %%
#criar o dicionário:
#Podemos criar tanto junto na ordem, quando indentado.
pessoa = {'nome': 'Alice',
          'idade': 25,'cidade':
          'São Paulo'}
print(pessoa)
# Out:
# {'nome': 'Alice', 'idade': 25, 'cidade': 'São Paulo'}

# %%
#Exemplo mais aprofundado de dicionário, a chave fica do lado esquerdo chave: valor e os valores ficam do lado direito
pessoa = {'nome': 'Alice',
          'idade': 25,
          'cidade': 'São Paulo'}
print(pessoa['nome']) #chamamos o valor da chave, e nos retornou o valor.
print(pessoa['cidade'])
# Out:
# Alice
# São Paulo

# %%
#Dicionário vazio, incluindo valores:
pessoa = {}
print(pessoa)
print("___________________________________________")
pessoa['nome'] = 'Alice' #fazendo entre a chave e dando o valor à ela
pessoa['idade'] = 26
print(pessoa) #quando os valores são inseridos

"""
1. Se a chave JÁ EXISTE: o valor associado é alterado para o novo valor.
2. Se a chave NÃO EXISTE: a nova chave será adicionada ao dicionário.
"""
# Out:
# {}
# ___________________________________________
# {'nome': 'Alice', 'idade': 26}

# %%
#Primeiro item da lista é a quantidade por banheiro e o #segundo é o estoque (em unidades)
banheiro_UFABC = {
"papel_higienico": [ 10, 500],
"alcool_gel": [ 2, 200],
"sabonete": [ 8, 750],
"papel_toalha": [ 4, 1000],
}
print(banheiro_UFABC)
# Out:
# {'papel_higienico': [10, 500], 'alcool_gel': [2, 200], 'sabonete': [8, 750], 'papel_toalha': [4, 1000]}

# %%
#DESAFIO PARTE 4
Estoque = {}
while True:
  Nome_produto = input("Digite o nome do produto ")
  if Nome_produto == "":
    break
  Preço = float(input("Digite o preço do produto "))
  Quantidade = int(input("Digite a quantidade disponível do produto "))
  Estoque[Nome_produto] = [Preço,Quantidade]
  #Estoque[Nome_produto] = {"Preço":Preço,"Quantidade":Quantidade} - alternativa
  print("Produto cadastrado")
# Out:
# Digite o nome do produto Colher
# Digite o preço do produto 10
# Digite a quantidade disponível do produto 60
# Produto cadastrado
# Digite o nome do produto Banana
# Digite o preço do produto 10
# Digite a quantidade disponível do produto 30
# Produto cadastrado
# Digite o nome do produto Morango
# Digite o preço do produto 5
# Digite a quantidade disponível do produto 40
# Produto cadastrado
# Digite o nome do produto Beringela
# Digite o preço do produto 3
# Digite a quantidade disponível do produto 50
# Produto cadastrado
# Digite o nome do produto

# %%
#Para verificar se uma chave pertence ao dicionário, podemos usar o operador in: chave in dicionario
pessoa = {'nome': 'Alice',
          'idade': 25,
          'cidade': 'São Paulo'}

print('niver' in pessoa)

print('idade' in pessoa)
# Out:
# False
# True

# %%
#Atividade
tabela = { "Arroz": 18.00,
           "Feijão": 7.99,
           "Alface": 1.98,
           "Batata": 4.59,
           "Macarrão": 2.99 }
while True:
  produto = input("Digite o nome do produto, ou fim para terminar: ")
  if produto == "fim":
     break
  if produto in tabela:
     print("Preço: R$", tabela[produto])
  else:
     print("Produto não encontrado!")

print("___________________________________________")
#para encontrar o produto
nome = input("Digite o nome do produto ")
if nome in tabela:
  print(f"Preço: {tabela[nome]['Preço']} Quantidade: {tabela[nome]['Quantidade']}")
else:
  print("Produto não encontrado")
# Out:
# Digite o nome do produto, ou fim para terminar: Batata
# Preço: R$ 4.59
# Digite o nome do produto, ou fim para terminar: fim
# ___________________________________________
# Digite o nome do produto arroz
# Produto não encontrado

# %%
#DESAFIO - DIA 2 -
comando1 = input("Vamos começar? S/N: ")
print("___________________________________________")
comando2 = "N"
estoque = {} #para fazer um novo dicionário
while comando1 != comando2:
    n = input("Nome: ")
    p = input("Preço: ")
    q = input("Quantidade em estoque: ")
    estoque[n] = [p,q]
    print("----------------------------------------------")
    print(f"Produto Cadastrado:", estoque)
    print("___________________________________________")
    comando1 = input("Vamos continuar? S/N: ")

print(f"Foram cadastrados", len(estoque), "produtos!")
print("----------------------------------------------")

for valor_e_quantidade in estoque:
  print(valor_e_quantidade)
  print("Preço:", estoque[valor_e_quantidade][0])
  print("Quantidade:", estoque[valor_e_quantidade][1])

#pesquisar produto e saber os seus valores
while consultar != "fim":
    consultar = input("Digite o produto que quer consultar ou fim: ")
    print("Preço:", estoque[consultar][0])
    print("Quantidade:", estoque[consultar][1])
else:
    print("Produto indisponível.")
    consultar = input("Digite o produto que quer consultar ou fim: ")
# Out:
# Vamos começar? S/N: N
# ___________________________________________
# Foram cadastrados 0 produtos!
# ----------------------------------------------
# Produto indisponível.
# Digite o produto que quer consultar ou fim: fim

# %%
# Dia 2 - Atividade 4
compras = {
    "lista_eu" : {"mouse" : 4,
                  "caderneta" : 5,
                  "canetas" : 10
                  }, #Não esquecer de colocar uma virgula!!
    "lista_amiga" : {"mouse": 6,
                     "caderneta" : 5,
                     "canetas" : 10
                     }
}
for lista in compras:
    print(lista, "mouse:", compras[lista]["mouse"], "cadernetas:", compras[lista]["caderneta"], "canetas:", compras[lista]["caderneta"])
# Out:
# lista_eu mouse: 4 cadernetas: 5 canetas: 5
# lista_amiga mouse: 6 cadernetas: 5 canetas: 5

# %%
# Dia 2 - FUNÇÕES E MODULARIZAÇÃO - 155
def hello(nome):
    print('Olá ', nome)

meu_nome = input('Digite seu nome: ')
hello(meu_nome)
# Out:
# Digite seu nome: Andrea
# Olá  Andrea

# %%
#exemplos
def soma(a,b):
      print(a+b)

soma(2,9)
soma(7,8)
soma(10,15)
# Out:
# 11
# 15
# 25

# %%
#exemplos
def maior(x,y):
      if x > y:
         print(x)
      else:
         print(y)

maior(4,7)
# Out:
# 7

# %%
def soma(a,b):
    return(a+b)
print(soma(2,9))

print("___________________________________________")

def ehpar(x):
    return(x % 2 == 0)
print(ehpar(2))
print(ehpar(3))
print(ehpar(10))
# Out:
# 11
# ___________________________________________
# True
# False
# True

# %%
#DESAFIO - DIA 2 - FUNÇÕES
comando1 = input("Vamos começar? S/N: ")
print("______________________________________________")

comando2 = "N"
estoque = {} #para fazer um novo dicionário vazio

def verificar_estoque(nome_do_produto):
  if nome_do_produto in estoque:
    return True
  else:
    return False

while comando1 != comando2:
    n = input("Nome: ")
    if verificar_estoque(n):
        print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        print("Produto já cadastrado!")
        print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        resposta = input("Quer cadastrar um novo produto? S/N: ")
    else:
        p = input("Preço: ")
        q = input("Quantidade em estoque: ")
        estoque[n] = [p,q]
        print("----------------------------------------------")
        print(f"Produto Cadastrado:", estoque)
        print("______________________________________________")
        comando1 = input("Vamos continuar? S/N: ")

print(f"Foram cadastrados", len(estoque), "produtos!")
print("----------------------------------------------")

for valor_e_quantidade in estoque:
    print(valor_e_quantidade)
    print("Preço: R$",estoque[valor_e_quantidade][0],",00")
    print("Quantidade:", estoque[valor_e_quantidade][1])
    print("______________________________________________")
# Out:
# Vamos começar? S/N: S
# ______________________________________________
# Nome: Banana
# Preço: 10
# Quantidade em estoque: 40
# ----------------------------------------------
# Produto Cadastrado: {'Banana': ['10', '40']}
# ______________________________________________
# Vamos continuar? S/N: S
# Nome: Uvas
# Preço: 5
# Quantidade em estoque: 50
# ----------------------------------------------
# Produto Cadastrado: {'Banana': ['10', '40'], 'Uvas': ['5', '50']}
# ______________________________________________
# Vamos continuar? S/N: S
# Nome: Banana
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Produto já cadastrado!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Quer cadastrar um novo produto? S/N: S
# Nome: Uvas
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Produto já cadastrado!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Quer cadastrar um novo produto? S/N: S
# Nome: Cabeça
# Preço: 12000
# Quantidade em estoque: 5
# ...

# %%
#DESAFIO - DIA 2 - INICIAR UMA VENDA
comando1 = input("Vamos começar a cadastrar? S/N: ")
print("______________________________________________")

comando2 = "N"
estoque = {} #para fazer um novo dicionário vazio

def verificar_estoque(nome_do_produto):
  if nome_do_produto in estoque:
    return True
  else:
    return False

while comando1 != comando2:
    n = input("Nome: ")
    if verificar_estoque(n):
        print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        print("Produto já cadastrado!")
        print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        resposta = input("Quer cadastrar um novo produto? S/N: ")
    else:
        p = int(input("Preço: "))
        q = int(input("Quantidade em estoque: "))
        estoque[n] = [p,q]
        print("----------------------------------------------")
        print(f"Produto Cadastrado:", estoque)
        print("______________________________________________")
        comando1 = input("Vamos continuar? S/N: ")

print(f"Foram cadastrados", len(estoque), "produtos!")
print("----------------------------------------------")

for produto in estoque:
    print(produto)
    print("Preço: R$",estoque[produto][0],",00")
    print("Quantidade:", estoque[produto][1])
    print("______________________________________________")

print("VAMOS INICIAR UMA VENDA!")
print("")
#Para verificar a existência do produto em nosso estoque
def mais_verificar_estoque(nome_produto):
  if nome_produto in estoque:
    return True
  else:
    return False

historico = {}
total_de_compras = 0
valor_produto = 0
valor_total_de_tudo = 0
while compra != "":
    compra = input("Digite o produto desejado: ")
    if mais_verificar_estoque(compra) == False:
        print("Sem estoque no momento 😢")
        break
    else:
        print("Disponível em estoque!")
        quantidade = int(input("Escreva a quantidade requerida: "))
        valor_produto = estoque[compra][0]
        total_de_compras = valor_produto * quantidade
        valor_total_de_tudo = valor_total_de_tudo + (valor_produto * quantidade)
        print("O valor total da compra está em: R$", valor_total_de_tudo)

    mais = input("Quer comprar mais produtos? S/N: ")
    if mais == "N":
        print("Volte sempre!")
        break


#CÓDIGO EM ANDAMENTO, RESOLUÇÃO DAS VOZES DA MINHA CABEÇA
# Out:
# Vamos começar a cadastrar? S/N: S
# ______________________________________________
# Nome: Morango
# Preço: 10
# Quantidade em estoque: 34
# ----------------------------------------------
# Produto Cadastrado: {'Morango': [10, 34]}
# ______________________________________________
# Vamos continuar? S/N: S
# Nome: Mexirica
# Preço: 30
# Quantidade em estoque: 20
# ----------------------------------------------
# Produto Cadastrado: {'Morango': [10, 34], 'Mexirica': [30, 20]}
# ______________________________________________
# Vamos continuar? S/N: N
# Foram cadastrados 2 produtos!
# ----------------------------------------------
# Morango
# Preço: R$ 10 ,00
# Quantidade: 34
# ______________________________________________
# Mexirica
# Preço: R$ 30 ,00
# Quantidade: 20
# ______________________________________________
# VAMOS INICIAR UMA VENDA!
#
# Digite o produto desejado: Morango
# Disponível em estoque!
# Escreva a quantidade requerida: 6
# O valor total da compra está em: R$ 60
# ...

# %%
#ATIVIDADE - FUNÇÃO DEF - APROFUNDADO
"""
Ana está cadastrando clientes em um sistema. Para seguir com o cadastro, o CPF precisa ter exatamente 11 dígitos numéricos.

Crie uma função cpf_valido(cpf) que recebe uma string e retorna se o CPF é válido ou não (apenas pela contagem de dígitos).
"""
validoo = input("Digite o CPF: ")
def cpf_valido(numeros):
  if len(numeros) == 11:
    print("CPF válido.")
  else:
    print("CPF não válido")
cpf_valido(validoo)
# Out:
# Digite o CPF: 12345678910
# CPF válido.

# %%
#ATIVIDADE NA 191

# %%
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2025-10-04 14:19:03.129439
